# %%
import pysc2
help(pysc2)
# Out:
# Help on package pysc2:
#
# NAME
#     pysc2 - PySC2 module: https://github.com/deepmind/pysc2 .
#
# PACKAGE CONTENTS
#     agents (package)
#     bin (package)
#     env (package)
#     lib (package)
#     maps (package)
#     run_configs (package)
#     tests (package)
#
# FUNCTIONS
#     load_tests(loader, standard_tests, unused_pattern)
#         Our tests end in `_test.py`, so need to override the test discovery.
#
# FILE
#     /usr/local/lib/python3.6/dist-packages/pysc2/__init__.py

# %%
from pysc2 import agents
help(pysc2.agents)
# Out:
# Help on package pysc2.agents in pysc2:
#
# NAME
#     pysc2.agents
#
# DESCRIPTION
#     # Copyright 2017 Google Inc. All Rights Reserved.
#     #
#     # Licensed under the Apache License, Version 2.0 (the "License");
#     # you may not use this file except in compliance with the License.
#     # You may obtain a copy of the License at
#     #
#     #      http://www.apache.org/licenses/LICENSE-2.0
#     #
#     # Unless required by applicable law or agreed to in writing, software
#     # distributed under the License is distributed on an "AS-IS" BASIS,
#     # WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#     # See the License for the specific language governing permissions and
#     # limitations under the License.
#
# PACKAGE CONTENTS
#     base_agent
#     random_agent
#     scripted_agent
#
# FILE
#     /usr/local/lib/python3.6/dist-packages/pysc2/agents/__init__.py

# %%
from pysc2.agents import random_agent
help(random_agent)
# Out:
# Help on module pysc2.agents.random_agent in pysc2.agents:
#
# NAME
#     pysc2.agents.random_agent - A random agent for starcraft.
#
# CLASSES
#     pysc2.agents.base_agent.BaseAgent(builtins.object)
#         RandomAgent
#
#     class RandomAgent(pysc2.agents.base_agent.BaseAgent)
#      |  A random agent for starcraft.
#      |
#      |  Method resolution order:
#      |      RandomAgent
#      |      pysc2.agents.base_agent.BaseAgent
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  step(self, obs)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from pysc2.agents.base_agent.BaseAgent:
#      |
#      |  __init__(self)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  reset(self)
#      |
#      |  setup(self, obs_spec, action_spec)
#      |
#      |  ----------------------------------------------------------------------
# ...

# %%
from pysc2 import bin
help(pysc2.bin)
# Out:
# Help on package pysc2.bin in pysc2:
#
# NAME
#     pysc2.bin
#
# DESCRIPTION
#     # Copyright 2017 Google Inc. All Rights Reserved.
#     #
#     # Licensed under the Apache License, Version 2.0 (the "License");
#     # you may not use this file except in compliance with the License.
#     # You may obtain a copy of the License at
#     #
#     #      http://www.apache.org/licenses/LICENSE-2.0
#     #
#     # Unless required by applicable law or agreed to in writing, software
#     # distributed under the License is distributed on an "AS-IS" BASIS,
#     # WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#     # See the License for the specific language governing permissions and
#     # limitations under the License.
#
# PACKAGE CONTENTS
#     agent
#     agent_remote
#     benchmark_observe
#     gen_actions
#     gen_units
#     gen_versions
#     map_list
#     mem_leak_check
#     play
#     play_vs_agent
#     replay_actions
#     replay_info
# ...

# %%
from pysc2.bin import play
help(pysc2.bin.play)
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Help on module pysc2.bin.play in pysc2.bin:
#
# NAME
#     pysc2.bin.play - Run SC2 to play a game or a replay.
#
# FUNCTIONS
#     entry_point()
#
#     get_replay_version(replay_data)
#
#     main(unused_argv)
#         Run SC2 to play a game or a replay.
#
# DATA
#     FLAGS = <absl.flags._flagvalues.FlagValues object>
#     absolute_import = _Feature((2, 5, 0, 'alpha', 1), (3, 0, 0, 'alpha', 0...
#     division = _Feature((2, 2, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 8192...
#     print_function = _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0)...
#
# FILE
#     /usr/local/lib/python3.6/dist-packages/pysc2/bin/play.py

# %%
from pysc2 import env
help(pysc2.env)
# Out:
# Help on package pysc2.env in pysc2:
#
# NAME
#     pysc2.env
#
# DESCRIPTION
#     # Copyright 2017 Google Inc. All Rights Reserved.
#     #
#     # Licensed under the Apache License, Version 2.0 (the "License");
#     # you may not use this file except in compliance with the License.
#     # You may obtain a copy of the License at
#     #
#     #      http://www.apache.org/licenses/LICENSE-2.0
#     #
#     # Unless required by applicable law or agreed to in writing, software
#     # distributed under the License is distributed on an "AS-IS" BASIS,
#     # WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#     # See the License for the specific language governing permissions and
#     # limitations under the License.
#
# PACKAGE CONTENTS
#     available_actions_printer
#     base_env_wrapper
#     environment
#     host_remote_agent
#     lan_sc2_env
#     mock_sc2_env
#     mock_sc2_env_comparison_test
#     mock_sc2_env_test
#     remote_sc2_env
# ...

# %%
from pysc2.env import environment
help(environment)
# Out:
# Help on module pysc2.env.environment in pysc2.env:
#
# NAME
#     pysc2.env.environment - Python RL Environment API.
#
# CLASSES
#     builtins.object
#         Base
#     enum.IntEnum(builtins.int, enum.Enum)
#         StepType
#     TimeStep(builtins.tuple)
#         TimeStep
#
#     class Base(builtins.object)
#      |  Abstract base class for Python RL environments.
#      |
#      |  Methods defined here:
#      |
#      |  __del__(self)
#      |
#      |  __enter__(self)
#      |      Allows the environment to be used in a with-statement context.
#      |
#      |  __exit__(self, unused_exception_type, unused_exc_value, unused_traceback)
#      |      Allows the environment to be used in a with-statement context.
#      |
#      |  action_spec(self)
#      |      Defines the actions that should be provided to `step`.
#      |
#      |      Returns:
#      |        A tuple of specs (one per agent), where each spec is something that
# ...

# %%
from pysc2.env import sc2_env
help(sc2_env)
# Out:
# Help on module pysc2.env.sc2_env in pysc2.env:
#
# NAME
#     pysc2.env.sc2_env - A Starcraft II environment.
#
# CLASSES
#     builtins.tuple(builtins.object)
#         Bot
#     enum.IntEnum(builtins.int, enum.Enum)
#         Difficulty
#         Race
#     pysc2.env.environment.Base(builtins.object)
#         SC2Env
#     Agent(builtins.tuple)
#         Agent
#
#     class Agent(Agent)
#      |  Agent(race, name)
#      |
#      |  Method resolution order:
#      |      Agent
#      |      Agent
#      |      builtins.tuple
#      |      builtins.object
#      |
#      |  Static methods defined here:
#      |
#      |  __new__(cls, race, name=None)
#      |      Create new instance of Agent(race, name)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
# ...

# %%
from pysc2 import lib
help(pysc2.lib)
# Out:
# Help on package pysc2.lib in pysc2:
#
# NAME
#     pysc2.lib
#
# DESCRIPTION
#     # Copyright 2017 Google Inc. All Rights Reserved.
#     #
#     # Licensed under the Apache License, Version 2.0 (the "License");
#     # you may not use this file except in compliance with the License.
#     # You may obtain a copy of the License at
#     #
#     #      http://www.apache.org/licenses/LICENSE-2.0
#     #
#     # Unless required by applicable law or agreed to in writing, software
#     # distributed under the License is distributed on an "AS-IS" BASIS,
#     # WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#     # See the License for the specific language governing permissions and
#     # limitations under the License.
#
# PACKAGE CONTENTS
#     actions
#     colors
#     features
#     features_test
#     gfile
#     metrics
#     named_array
#     named_array_test
#     point
#     point_flag
#     point_test
#     portspicker
#     portspicker_test
# ...

# %%
from pysc2 import maps
help(pysc2.maps)
# Out:
# Help on package pysc2.maps in pysc2:
#
# NAME
#     pysc2.maps - Register/import the maps, and offer a way to create one by name.
#
# DESCRIPTION
#     Users of maps should import this module:
#       from pysc2 import maps
#     and create the maps by name:
#       maps.get("MapName")
#
#     If you want to create your own map, then import the map lib and subclass Map.
#     Your subclass will be implicitly registered as a map that can be constructed by
#     name, as long as it is imported somewhere.
#
# PACKAGE CONTENTS
#     ladder
#     lib
#     melee
#     mini_games
#
# DATA
#     absolute_import = _Feature((2, 5, 0, 'alpha', 1), (3, 0, 0, 'alpha', 0...
#     division = _Feature((2, 2, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 8192...
#     print_function = _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0)...
#
# FILE
#     /usr/local/lib/python3.6/dist-packages/pysc2/maps/__init__.py

# %%
from pysc2 import run_configs
help(pysc2.run_configs)
# Out:
# Help on package pysc2.run_configs in pysc2:
#
# NAME
#     pysc2.run_configs - Configs for various ways to run starcraft.
#
# PACKAGE CONTENTS
#     lib
#     platforms
#
# FUNCTIONS
#     get()
#         Get the config chosen by the flags.
#
# DATA
#     FLAGS = <absl.flags._flagvalues.FlagValues object>
#     absolute_import = _Feature((2, 5, 0, 'alpha', 1), (3, 0, 0, 'alpha', 0...
#     division = _Feature((2, 2, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 8192...
#     print_function = _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0)...
#
# FILE
#     /usr/local/lib/python3.6/dist-packages/pysc2/run_configs/__init__.py

# %%
from pysc2 import tests
help(pysc2.tests)
# Out:
# Help on package pysc2.tests in pysc2:
#
# NAME
#     pysc2.tests
#
# DESCRIPTION
#     # Copyright 2017 Google Inc. All Rights Reserved.
#     #
#     # Licensed under the Apache License, Version 2.0 (the "License");
#     # you may not use this file except in compliance with the License.
#     # You may obtain a copy of the License at
#     #
#     #      http://www.apache.org/licenses/LICENSE-2.0
#     #
#     # Unless required by applicable law or agreed to in writing, software
#     # distributed under the License is distributed on an "AS-IS" BASIS,
#     # WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#     # See the License for the specific language governing permissions and
#     # limitations under the License.
#
# PACKAGE CONTENTS
#     debug_test
#     dummy_observation
#     dummy_observation_test
#     easy_scripted_test
#     host_remote_agent_test
#     maps_test
#     multi_player_env_test
#     multi_player_test
#     obs_spec_test
# ...
